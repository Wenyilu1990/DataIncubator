# %%
import os, sys, time
import cv2
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

#%matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
TRAIN_SAMPLE_FOLDER = 'dfdc_train_part_0'

# %%
train_dir = TRAIN_SAMPLE_FOLDER
train_videos = sorted([x for x in os.listdir(train_dir) if x[-4:] == ".mp4"])
len(train_videos)
# Out:
# 1334

# %%
print("PyTorch version:", torch.__version__)
print("CUDA version:", torch.version.cuda)
print("cuDNN version:", torch.backends.cudnn.version())
# Out:
# PyTorch version: 1.3.1
# CUDA version: None
# cuDNN version: None

# %%
gpu = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
gpu
# Out:
# device(type='cpu')

# %%
sys.path.insert(0, "BlazeFace-PyTorch")

# %%
from blazeface import BlazeFace
facedet = BlazeFace().to(gpu)
facedet.load_weights("BlazeFace-PyTorch/blazeface.pth")
facedet.load_anchors("BlazeFace-PyTorch/anchors.npy")
_ = facedet.train(False)

# %%
from read_video_1 import VideoReader
from face_extract_1 import FaceExtractor

# %%
frames_per_video = 17

video_reader = VideoReader()
video_read_fn = lambda x: video_reader.read_frames(x, num_frames=frames_per_video)
face_extractor = FaceExtractor(video_read_fn, facedet)

# %%
#input_size = 224

# %%
#facedet.input_size = input_size
#facedet.input_size

# %%
def plot_detections(img, detections, with_keypoints=True):
    fig, ax = plt.subplots(1, figsize=(10, 10))
    ax.grid(False)
    ax.imshow(img)
    
    if isinstance(detections, torch.Tensor):
        detections = detections.cpu().numpy()

    if detections.ndim == 1:
        detections = np.expand_dims(detections, axis=0)

    print("Found %d faces" % detections.shape[0])
        
    for i in range(detections.shape[0]):
        ymin = detections[i, 0] * img.shape[0]
        xmin = detections[i, 1] * img.shape[1]
        ymax = detections[i, 2] * img.shape[0]
        xmax = detections[i, 3] * img.shape[1]

        rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                 linewidth=1, edgecolor="r", facecolor="none", 
                                 alpha=detections[i, 16])
        
        ax.add_patch(rect)

        if with_keypoints:
            for k in range(6):
                kp_x = detections[i, 4 + k*2    ] * img.shape[1]
                kp_y = detections[i, 4 + k*2 + 1] * img.shape[0]
                circle = patches.Circle((kp_x, kp_y), radius=0.5, linewidth=1, 
                                        edgecolor="lightskyblue", facecolor="none", 
                                        alpha=detections[i, 16])
                ax.add_patch(circle)
        
    plt.show()

# %%
def read_frame(video_path):
    capture = cv2.VideoCapture(video_path)
    ret, frame = capture.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    frame = cv2.resize(frame, (128, 128))
    capture.release()
    return frame

# %%
from torchvision.transforms import Normalize

mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]
normalize_transform = Normalize(mean, std)

# %%
def isotropically_resize_image(img, size, resample=cv2.INTER_AREA):
    h, w = img.shape[:2]
    if w > h:
        h = h * size // w
        w = size
    else:
        w = w * size // h
        h = size

    resized = cv2.resize(img, (w, h), interpolation=resample)
    return resized


def make_square_image(img):
    h, w = img.shape[:2]
    size = max(h, w)
    t = 0
    b = size - h
    l = 0
    r = size - w
    return cv2.copyMakeBorder(img, t, b, l, r, cv2.BORDER_CONSTANT, value=0)

# %%
import torch.nn as nn
import torchvision.models as models

class MyResNeXt(models.resnet.ResNet):
    def __init__(self, training=True):
        super(MyResNeXt, self).__init__(block=models.resnet.Bottleneck,
                                        layers=[3, 4, 6, 3], 
                                        groups=32, 
                                        width_per_group=4)
        self.fc = nn.Linear(2048, 1)

# %%
checkpoint = torch.load("resnext.pth", map_location=gpu)

model = MyResNeXt().to(gpu)
model.load_state_dict(checkpoint)
_ = model.eval()

del checkpoint

# %%
def predict_on_video(video_path, batch_size):
    try:
        # Find the faces for N frames in the video.
        faces = face_extractor.process_video(video_path)

        # Only look at one face per frame.
        face_extractor.keep_only_best_face(faces)
        
        if len(faces) > 0:
            # NOTE: When running on the CPU, the batch size must be fixed
            # or else memory usage will blow up. (Bug in PyTorch?)
            x = np.zeros((batch_size, input_size, input_size, 3), dtype=np.uint8)

            # If we found any faces, prepare them for the model.
            n = 0
            for frame_data in faces:
                for face in frame_data["faces"]:
                    # Resize to the model's required input size.
                    # We keep the aspect ratio intact and add zero
                    # padding if necessary.                    
                    resized_face = isotropically_resize_image(face, input_size)
                    resized_face = make_square_image(resized_face)

                    if n < batch_size:
                        x[n] = resized_face
                        n += 1
                    else:
                        print("WARNING: have %d faces but batch size is %d" % (n, batch_size))
                    
                    # Test time augmentation: horizontal flips.
                    # TODO: not sure yet if this helps or not
                    #x[n] = cv2.flip(resized_face, 1)
                    #n += 1

            if n > 0:
                x = torch.tensor(x, device=gpu).float()

                # Preprocess the images.
                x = x.permute((0, 3, 1, 2))

                for i in range(len(x)):
                    x[i] = normalize_transform(x[i] / 255.)

                # Make a prediction, then take the average.
                with torch.no_grad():
                    y_pred = model(x)
                    y_pred = torch.sigmoid(y_pred.squeeze())
                    return y_pred[:n].mean().item()

    except Exception as e:
        print("Prediction error on video %s: %s" % (video_path, str(e)))

    return 0.5

# %%
#video_path = TRAIN_SAMPLE_FOLDER
#filenames = list(os.listdir(os.path.join(TRAIN_SAMPLE_FOLDER)))
#filenames
input_dir = train_dir
video_path = os.path.join(input_dir, np.random.choice(os.listdir(input_dir)))
video_path
# Out:
# 'dfdc_train_part_0/jkxjvuioek.mp4'

# %%
frame = read_frame(video_path)

# %%
plt.imshow(frame)

# %%
detections = facedet.predict_on_image(frame)
detections.shape
# Out:
# torch.Size([1, 17])

# %%
detections
# Out:
# tensor([[0.3783, 0.6644, 0.5528, 0.8389, 0.6890, 0.4337, 0.7354, 0.4268, 0.6814,
#          0.4657, 0.7006, 0.5017, 0.7243, 0.4504, 0.8344, 0.4385, 0.8813]])

# %%
plot_detections(frame, detections)
# Out:
# Found 1 faces

# %%
frame1 = read_frame("dfdc_train_part_0/hhyxweyjlt.mp4")
frame2 = read_frame("dfdc_train_part_0/shnsajrsow.mp4")

batch = np.stack([frame1, frame2])
batch.shape
# Out:
# (2, 128, 128, 3)

# %%
# %time detections = facedet.predict_on_batch(batch)
# Out:
# CPU times: user 37.7 ms, sys: 8.57 ms, total: 46.2 ms
# Wall time: 44.8 ms

# %%
plot_detections(frame1, detections[0])
# Out:
# Found 1 faces

# %%
plot_detections(frame2, detections[1])
# Out:
# Found 1 faces

# %%
facedet.input_size
# Out:
# (128, 128)

# %%
# Find the faces for N frames in the video.
faces = face_extractor.process_video(video_path)

# %%
from concurrent.futures import ThreadPoolExecutor

def predict_on_video_set(videos, num_workers):
    def process_file(i):
        filename = videos[i]
        y_pred = predict_on_video(os.path.join(test_dir, filename), batch_size=frames_per_video)
        return y_pred

    with ThreadPoolExecutor(max_workers=num_workers) as ex:
        predictions = ex.map(process_file, range(len(videos)))

    return list(predictions)

# %%
speed_test = True  # you have to enable this manually

# %%
#test_videos = train_list

# %%
if speed_test:
    start_time = time.time()
    speedtest_videos = train_videos[:5]
    predictions = predict_on_video_set(speedtest_videos, num_workers=4)
    elapsed = time.time() - start_time
    print("Elapsed %f sec. Average per video: %f sec." % (elapsed, elapsed / len(speedtest_videos)))
# Out:
# Prediction error on video dfdc_train_part_0/aaqaifqrwn.mp4: 'BlazeFace' object has no attribute 'input_size'Prediction error on video dfdc_train_part_0/aayrffkzxn.mp4: 'BlazeFace' object has no attribute 'input_size'
#
# Prediction error on video dfdc_train_part_0/abhggqdift.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/acagallncj.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/acdkfksyev.mp4: 'BlazeFace' object has no attribute 'input_size'
# Elapsed 0.002338 sec. Average per video: 0.000468 sec.

# %%
train_list = list(os.listdir(os.path.join(TRAIN_SAMPLE_FOLDER)))
#len(train_list)
test_dir = TRAIN_SAMPLE_FOLDER

# %%
predictions = predict_on_video_set(train_list, num_workers=4)
# Out:
# Prediction error on video dfdc_train_part_0/lmpfbmeade.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/slvtfdxsmd.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/edqhdckynd.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/tjqjumumjm.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/yckyxxeqtd.mp4: 'BlazeFace' object has no attribute 'input_size'Prediction error on video dfdc_train_part_0/pllpxvzpok.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/yklkjjlpyj.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/tufacqdefx.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/pkkmysbvfh.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/bqefygjsnx.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/omrtielsni.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/epeyujjlhn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/dgyeaodnzw.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/iurmztyqed.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/fsaronfupy.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/fonrexmbzz.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/whgfvrprxj.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/xdezcezszc.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/hhyxweyjlt.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/goxbkycgkg.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/myszscymzv.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/nrdnytturz.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/tbujzmjpsl.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/ywajbwquvw.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/hsbljbsgxr.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/lbsltufgrh.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/epwesrdmpt.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/hbtcuqhwyy.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/lznkdhgwms.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/kkxgqvpusd.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/mcbubknuyd.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/mqmgqlbzct.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/dyjklprkoc.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/yfzulfwjue.mp4: 'BlazeFace' object has no attribute 'input_size'Prediction error on video dfdc_train_part_0/fhgnmqzfca.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/fzqnoyzhbm.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/ahhdprhoww.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/osaesqnzgw.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/qnghrfvbgb.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/ecnmwevrxo.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/dhyybsrvwc.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/brtujopkby.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/skewcclbhg.mp4: 'BlazeFace' object has no attribute 'input_size'Prediction error on video dfdc_train_part_0/llseqxuobs.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/drmtvuyoam.mp4: 'BlazeFace' object has no attribute 'input_size'
#
#
#
# Prediction error on video dfdc_train_part_0/ujvrrbmmye.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/tkvhbpjuvd.mp4: 'BlazeFace' object has no attribute 'input_size'Prediction error on video dfdc_train_part_0/mdihiuwzea.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/jjguwagxur.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/sakziaduuh.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/dlpaibcwsy.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/hgjdosshpt.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/awigxxbbpb.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/tmgdhykjbo.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/hplxtssgnz.mp4: 'BlazeFace' object has no attribute 'input_size'Prediction error on video dfdc_train_part_0/kcidxranvr.mp4: 'BlazeFace' object has no attribute 'input_size'
#
# Prediction error on video dfdc_train_part_0/tqmmvmxqpn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/qnlyrlrnmn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/yiabajckla.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/gmaghrdamw.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/titungrbgd.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/vwbzhldrub.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/aeqpxjlbwu.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/lmjzfqizks.mp4: 'BlazeFace' object has no attribute 'input_size'Prediction error on video dfdc_train_part_0
.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/bzxauvpscl.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/kpmieleslf.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/msfhpjlxya.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/kzezrsewki.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/yabvnuhvkn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/zbpwazdhtz.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/akpuczgfpk.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/zhopdnywsb.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/wdcrhqtjhf.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/xnkktewjmu.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/rdkqpgajlg.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/nweufafotd.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/tdspbqidzz.mp4: 'BlazeFace' object has no attribute 'input_size'Prediction error on video dfdc_train_part_0/tdontxxzek.mp4: 'BlazeFace' object has no attribute 'input_size'
#
#
# Prediction error on video dfdc_train_part_0/keuvybqsbr.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/lvuvvfmmli.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/izjvqhjokl.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/yrdqoqggkh.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/erbgcpjuzj.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/jbwtvoixgc.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/phjlaexgcl.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/ndrnxgzlmn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/mwrblsiixn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/pmmhsciico.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/bwlxucgxro.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/nwtdlrhqtf.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/xcmrhxjhfr.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/zwgrutmnsn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/xcruhaccxc.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/xbdqbydiwc.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/twxnazwxup.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/jgzwhkcrcc.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/zzlsynxeff.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/dxrqdhegop.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/wztythgahw.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/mnqxygpnmf.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/poxhzrfhha.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/wsxxdlhnhh.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/nbjwcgpeoi.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/opsjddoxui.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/bqamrsyvnf.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/bobihhgccf.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/hclsparpth.mp4: 'BlazeFace' object has no attribute 'input_size'Prediction error on video dfdc_train_part_0/oykagryjjd.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/dolynaukae.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/mmuolksboc.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/vsxuvpwqmm.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/fzvpbrzssi.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/vhqnsjfnsl.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/pktyfrvywo.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/zwsbdiyrpg.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/tjdxwdoumt.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/umpscxhfsk.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/exseruhiuk.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/fnslimfagb.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/ktwfxtzjbn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/vpsngiunec.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/uklvqsnxgv.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/irlgidcrvj.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/rnxnytbudq.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/dmirtsrziw.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/ofquuujxmu.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/awnfpubqmo.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/gecrjewspu.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/vxuhkqqaqv.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/jeosukfzow.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/tnrmnayszi.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/jkqivqkrnc.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/fxuxxtryjn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/xpzfhhwkwb.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/drooaxkvib.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/nzuvtbkmye.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/yfxtuimubx.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/cqbhgsmffd.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/mphsgertmm.mp4: 'BlazeFace' object has no attribute 'input_size'
#
#
# Prediction error on video dfdc_train_part_0/nzeqbdtlla.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/yzjzczodyz.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/khtwrijuqn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/zbvlctwcqr.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/kstmekinaw.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/wcqvzujamg.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/fopjiyxiqd.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/rdiogxmrwa.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/gfncmhgdio.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/ptgpqdnxtd.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/rfcgheaqwm.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/kjpxvgjsal.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/bbxqtnztyy.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/jranrlmuyk.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/dbhthsgych.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/rmufsuogzn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/cmoizyxqcc.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/kqlvggiqee.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/ohwwmrnowu.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/msfssnmldu.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/nqrcttpsme.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/yivspcmkbk.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/usqqvxcjmg.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/sttnfyptum.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/ebzsqgfpgh.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/oejlipxtai.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/rfeagdwnnn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/kedahvzait.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/euzlhrwolz.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/gumgvhycum.mp4: 'BlazeFace' object has no attribute 'input_size'Prediction error on video dfdc_train_part_0/zrplhkcesw.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/rpnetwqgqz.mp4: 'BlazeFace' object has no attribute 'input_size'Prediction error on video dfdc_train_part_0/oobmorozgk.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/vzcldbilmd.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/romzqwhhlb.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/zoleozlpfj.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/ushjtzfvyn.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/zvjzhuinck.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/hsosrxlnzk.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/ljxpqhvydy.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/cythdgxpdi.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/vqvmlwhabu.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/gfoozygynw.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/qcxkxcemcb.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/zigzhwlpcd.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/gnxlbuwucy.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/flilazlokf.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/wnlubukrki.mp4: 'BlazeFace' object has no attribute 'input_size'
# Prediction error on video dfdc_train_part_0/zpbggelffo.mp4: 'BlazeFace' object has no attribute 'input_size'

# %%
predictions
# Out:
# [0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  ...]
